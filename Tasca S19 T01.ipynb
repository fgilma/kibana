# %% [markdown]
# # Nivell 1
#  #### Exercici 1
#  Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# Vamos a la web de [Elastic](https://www.elastic.co/es/) y descargamos los archivos comprimidos de ElasticSearch y Kibana. A continuación los descomprimimos. En sendas carpetas tenemos una carpeta bin. En la primera de ellas, ejecutamos el fichero elasticsearch.bat para iniciar ElasticSearch y una vez arrancado este servicio clicamos, en la segunda carpeta bin, sobre el fichero kibana.bat para arrancar Kibana.
#
# Para visualizar elasticsearch en el navegador vamos a la dirección localhost:9200 que nos muestra:

# %%
from PIL import Image
Image.open('elasticsearch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=607x433 at 0x247F492EB00>

# %% [markdown]
# Y para kibana escribimos localhost:5601

# %%
Image.open('kibana.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1894x896 at 0x247F49242E8>

# %% [markdown]
# Al iniciarlo, Kibana nos permite añadir los datos que queramos, en este caso elegimos uno de los que vienen como ejemplo: **ecommerce**.
#
# Kibana nos muestra diferentes gráficos que podemos añadir a un futuro dashboard y el conjunto de datos que contienen los distintos pedidos que se han realizado

# %%
#dataset ecommerce
Image.open('ordersCommerce.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1890x450 at 0x247F4924DD8>

# %%
#Diferentes gráficos que contiene el ejemplo
Image.open('graficos1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1863x758 at 0x247F492E4A8>

# %% [markdown]
# # Nivell 2
#  #### Exercici 1
#
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# A partir de la librería que tiene kibana creamos un dashboard personalizado para el ejemplo ecommerce que llamamos ITAcademy. En este caso, elegimos los siguientes componentes:
# - Formulario para poder seleccionar fabricantes, categoría y cantidad.
# - Un gráfico lineal con las ventas diarias.
# - Un mapa indicando las ventas por país.
# - Valor ingresos totales.
# - Indicador productos vendidos por día.(Gauge chart)
#
# #### Tigress Enterprises

# %%
# Filtramos por fabricante Tigress Enterprises y ropa de mujer
Image.open('dashboardTigress.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1803x790 at 0x247F492E908>

# %% [markdown]
# #### Microlutions

# %%
# Cambiamos datos del formulario y filtramos por fabricante Microlutions y ropa de hombre
Image.open('dashboardMicrolutions.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1815x808 at 0x247F492E860>

# %% [markdown]
# # Nivell 3
# #### Exercici 1
# Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %% [markdown]
# Creamos un nuevo dashboard llamado ITAcademy2 y vamos incorporando diferentes tipos de gráficos que kibana nos ofrece en su librería:
# - Gauge Chart o velocímetro, en este caso medimos los productos vendidos por día.
# - Control o para hacer filtros y visualizar los datos al detalle.
# - Markdown donde podemos poner cualquier tipo de texto para informar y mejorar el report.
# - Un gráfico lineal con las ventas diarias.
# - Pedidos, no es un gráfico pero permite visualizar la información somo si fuera una tabla.
# - Mapa con pedidos por país.
# - Pie graph, en este caso para visualizar las ventas por género.
# - Bag of words con los productos más vendidos.

# %%
#Parte1
Image.open('ITAcademy2part1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1857x843 at 0x247F492E9B0>

# %%
#Parte2
Image.open('ITAcademy2part2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1877x861 at 0x247F492EA58>
